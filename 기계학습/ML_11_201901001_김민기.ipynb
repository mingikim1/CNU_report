# %%
from tensorflow import keras

fmnist = keras.datasets.fashion_mnist

(x_train, y_train), (x_test, y_test) = fmnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 2s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 1s 0us/step

# %%
model1 = keras.models.Sequential( [
    keras.layers.Conv2D(input_shape = (28, 28, 1), activation = 'relu', kernel_size = (3, 3), filters = 128, strides = 1),
    keras.layers.MaxPooling2D((2, 2), strides = 2),
    keras.layers.Flatten(),
    keras.layers.Dense(14*14, activation = 'relu'),
    keras.layers.Dense(10, activation = 'softmax'),
])

model1.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
hist1 = model1.fit(x_train, y_train, epochs = 10, validation_data = (x_test, y_test))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 20s 5ms/step - loss: 1.1503 - accuracy: 0.8576 - val_loss: 0.3414 - val_accuracy: 0.8805
# Epoch 2/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2850 - accuracy: 0.8971 - val_loss: 0.3312 - val_accuracy: 0.8902
# Epoch 3/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2534 - accuracy: 0.9081 - val_loss: 0.3648 - val_accuracy: 0.8773
# Epoch 4/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2236 - accuracy: 0.9163 - val_loss: 0.3645 - val_accuracy: 0.8930
# Epoch 5/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1964 - accuracy: 0.9282 - val_loss: 0.3711 - val_accuracy: 0.8959
# Epoch 6/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1717 - accuracy: 0.9356 - val_loss: 0.3515 - val_accuracy: 0.8994
# Epoch 7/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1497 - accuracy: 0.9438 - val_loss: 0.4126 - val_accuracy: 0.8928
# Epoch 8/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1329 - accuracy: 0.9514 - val_loss: 0.4522 - val_accuracy: 0.8927
# Epoch 9/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1140 - accuracy: 0.9588 - val_loss: 0.4914 - val_accuracy: 0.8954
# Epoch 10/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1066 - accuracy: 0.9612 - val_loss: 0.5416 - val_accuracy: 0.8917

# %%
df1 = hist1.history
print("train_acc:\n{}".format(df1['accuracy']))
print("\ntest_acc:\n{}".format(df1['val_accuracy']))

hist1_Acc = df1['accuracy']
hist1_valAcc = df1['val_accuracy']
# Out:
# train_acc:
# [0.8575999736785889, 0.8970999717712402, 0.9080666899681091, 0.9163333177566528, 0.9281666874885559, 0.9356499910354614, 0.9438166618347168, 0.951449990272522, 0.9587500095367432, 0.9611666798591614]
#
# test_acc:
# [0.8805000185966492, 0.8902000188827515, 0.8773000240325928, 0.8930000066757202, 0.8959000110626221, 0.899399995803833, 0.892799973487854, 0.8927000164985657, 0.8953999876976013, 0.891700029373169]

# %%
x_train, x_test = x_train/255, x_test/255

# %%
model2 = keras.models.Sequential( [
    keras.layers.Conv2D(input_shape = (28, 28, 1), activation = 'relu', kernel_size = (3, 3), filters = 128, strides = 1),
    keras.layers.MaxPooling2D((2, 2), strides = 2),
    keras.layers.Flatten(),
    keras.layers.Dense(14*14, activation = 'relu'),
    keras.layers.Dense(10, activation = 'softmax'),
])

model2.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
hist2 = model2.fit(x_train, y_train, epochs = 10, validation_data = (x_test, y_test))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.3658 - accuracy: 0.8694 - val_loss: 0.2967 - val_accuracy: 0.8910
# Epoch 2/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2448 - accuracy: 0.9111 - val_loss: 0.2654 - val_accuracy: 0.9020
# Epoch 3/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1971 - accuracy: 0.9275 - val_loss: 0.2670 - val_accuracy: 0.9023
# Epoch 4/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1589 - accuracy: 0.9402 - val_loss: 0.2625 - val_accuracy: 0.9113
# Epoch 5/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1289 - accuracy: 0.9517 - val_loss: 0.2651 - val_accuracy: 0.9153
# Epoch 6/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1052 - accuracy: 0.9609 - val_loss: 0.2628 - val_accuracy: 0.9186
# Epoch 7/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0830 - accuracy: 0.9690 - val_loss: 0.2985 - val_accuracy: 0.9163
# Epoch 8/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0664 - accuracy: 0.9756 - val_loss: 0.3275 - val_accuracy: 0.9138
# Epoch 9/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0539 - accuracy: 0.9804 - val_loss: 0.3376 - val_accuracy: 0.9132
# Epoch 10/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0441 - accuracy: 0.9842 - val_loss: 0.3832 - val_accuracy: 0.9168

# %%
df2 = hist2.history
print("train_acc:\n{}".format(df2['accuracy']))
print("\ntest_acc:\n{}".format(df2['val_accuracy']))

hist2_Acc = df2['accuracy']
hist2_valAcc = df2['val_accuracy']
# Out:
# train_acc:
# [0.8694000244140625, 0.9110666513442993, 0.9274666905403137, 0.9401666522026062, 0.9516666531562805, 0.9609000086784363, 0.9689833521842957, 0.975600004196167, 0.9803666472434998, 0.9842000007629395]
#
# test_acc:
# [0.890999972820282, 0.9020000100135803, 0.9023000001907349, 0.911300003528595, 0.9153000116348267, 0.9186000227928162, 0.9162999987602234, 0.9138000011444092, 0.9132000207901001, 0.9168000221252441]

# %%
model3 = keras.models.Sequential( [
    keras.layers.Conv2D(input_shape = (28, 28, 1), activation = 'relu', kernel_size = (3, 3), filters = 64, strides = 1),
    keras.layers.MaxPooling2D((2, 2), strides = 2),
    keras.layers.Conv2D(padding = 'same', activation = 'relu', kernel_size = (3, 3), filters = 32, strides = 1),
    keras.layers.Flatten(),
    keras.layers.Dense(10*10, activation = 'relu'),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(10, activation = 'softmax'),
])

model3.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
hist3 = model3.fit(x_train, y_train, epochs = 10, validation_data = (x_test, y_test))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 11s 5ms/step - loss: 0.4286 - accuracy: 0.8457 - val_loss: 0.3016 - val_accuracy: 0.8903
# Epoch 2/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2787 - accuracy: 0.8977 - val_loss: 0.2641 - val_accuracy: 0.9010
# Epoch 3/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2305 - accuracy: 0.9140 - val_loss: 0.2495 - val_accuracy: 0.9077
# Epoch 4/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1998 - accuracy: 0.9265 - val_loss: 0.2406 - val_accuracy: 0.9131
# Epoch 5/10
# 1875/1875 [==============================] - 8s 5ms/step - loss: 0.1706 - accuracy: 0.9362 - val_loss: 0.2376 - val_accuracy: 0.9183
# Epoch 6/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1482 - accuracy: 0.9447 - val_loss: 0.2389 - val_accuracy: 0.9196
# Epoch 7/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1286 - accuracy: 0.9516 - val_loss: 0.2520 - val_accuracy: 0.9172
# Epoch 8/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1126 - accuracy: 0.9576 - val_loss: 0.2429 - val_accuracy: 0.9233
# Epoch 9/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0978 - accuracy: 0.9627 - val_loss: 0.2782 - val_accuracy: 0.9245
# Epoch 10/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0880 - accuracy: 0.9659 - val_loss: 0.2797 - val_accuracy: 0.9187

# %%
df3 = hist3.history
print("train_acc:\n{}".format(df3['accuracy']))
print("\ntest_acc:\n{}".format(df3['val_accuracy']))

hist3_Acc = df3['accuracy']
hist3_valAcc = df3['val_accuracy']
# Out:
# train_acc:
# [0.8457000255584717, 0.897683322429657, 0.9139666557312012, 0.9264833331108093, 0.9362499713897705, 0.9447000026702881, 0.9515833258628845, 0.9575666785240173, 0.9626666903495789, 0.9659166932106018]
#
# test_acc:
# [0.8902999758720398, 0.9010000228881836, 0.9077000021934509, 0.913100004196167, 0.9182999730110168, 0.9196000099182129, 0.9172000288963318, 0.92330002784729, 0.9244999885559082, 0.9186999797821045]

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize = (12, 4))
plt.subplot(1, 2, 1)
plt.plot(np.arange(len(hist1_Acc)), hist1_Acc, color = 'r', label = 'base')
plt.plot(np.arange(len(hist2_Acc)), hist2_Acc, color = 'b', label = 'base + norm')
plt.plot(np.arange(len(hist3_Acc)), hist3_Acc, color = 'black', label = 'layer + norm')
plt.title("accuracy")
plt.xlabel("Epoch")
plt.ylabel("accuracy")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(np.arange(len(hist1_valAcc)), hist1_valAcc, color = 'r', label = 'base')
plt.plot(np.arange(len(hist2_valAcc)), hist2_valAcc, color = 'b', label = 'base + norm')
plt.plot(np.arange(len(hist3_valAcc)), hist3_valAcc, color = 'black', label = 'layer + norm')
plt.title("accuracy")
plt.xlabel("Epoch")
plt.ylabel("accuracy")
plt.legend()
plt.show()
